# %%
from utils import *
# notebook uses global variables

# %matplotlib inline

# %%
paths_b1 = [
"./tmrca/N500_b1.0_m100_mu0_r5e-05_mus0_sc0_dc0_L1e4_sp0_s1/",
"./rerun/recovery_sweep/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov0/",
"./rerun/recovery_sweep/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov500/",
"./rerun/recovery_sweep/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov1000/",
"./rerun/recovery_sweep/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov2000/",
]

paths_b035 = [
    "./tmrca/N500_b0.35_m100_mu0_r5e-05_mus0_sc0_dc0_L1e4_sp0_s1/",
    "./rerun/recovery_sweep/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov0/",
    "./rerun/recovery_sweep/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov500/",
    "./rerun/recovery_sweep/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov1000/",
    "./rerun/recovery_sweep/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov2000/",
]

models = ["no sweep","0", "500", "1000", "2000"]

# %%
black_color_variation01 = sns.color_palette(['black'], 1)
black_color_variation01 = list(black_color_variation01[0])
black_color_variation01[0] = black_color_variation01[0] + 0.2
black_color_variation01[1] = black_color_variation01[1] + 0.2
black_color_variation01[2] = black_color_variation01[2] + 0.2

black_color_variation02 = sns.color_palette(['black'], 1)
black_color_variation02 = list(black_color_variation02[0])
black_color_variation02[0] = black_color_variation02[0] + 0.40
black_color_variation02[1] = black_color_variation02[1] + 0.40
black_color_variation02[2] = black_color_variation02[2] + 0.40

black_color_variation03 = sns.color_palette(['black'], 1)
black_color_variation03 = list(black_color_variation03[0])
black_color_variation03[0] = black_color_variation03[0] + 0.6
black_color_variation03[1] = black_color_variation03[1] + 0.6
black_color_variation03[2] = black_color_variation03[2] + 0.6

black_color_variation04 = sns.color_palette(['black'], 1)
black_color_variation04 = list(black_color_variation04[0])
black_color_variation04[0] = black_color_variation04[0] + 0.35
black_color_variation04[1] = black_color_variation04[1] + 0.35
black_color_variation04[2] = black_color_variation04[2] + 0.35


palette = sns.color_palette("hls", 8)
sb_050_color = palette[1]

sb_050_color_variation01 = list(sb_050_color)
sb_050_color_variation01[0] = sb_050_color_variation01[0] + 0.1
sb_050_color_variation01[1] = sb_050_color_variation01[1] + 0.1
sb_050_color_variation01[2] = sb_050_color_variation01[2] + 0.1
sb_050_color_variation01 = tuple(sb_050_color_variation01)

sb_050_color_variation02 = list(sb_050_color)
sb_050_color_variation02[0] = sb_050_color_variation02[0] - 0.1
sb_050_color_variation02[1] = sb_050_color_variation02[1] - 0.1
sb_050_color_variation02[2] = sb_050_color_variation02[2] - 0.1
sb_050_color_variation02 = tuple(sb_050_color_variation02)

palette = sns.color_palette("hls", 8)
sb_035_color = palette[4]

sb_035_color_variation01 = list(sb_035_color)


sb_035_color_variation01[0] = sb_035_color_variation01[0] - 0.1
sb_035_color_variation01[1] = sb_035_color_variation01[1] - 0.1
sb_035_color_variation01[2] = sb_035_color_variation01[2] - 0.1
sb_035_color_variation01 = tuple(sb_035_color_variation01)
sb_035_color_variation02 = list(sb_035_color)
sb_035_color_variation02[0] = sb_035_color_variation02[0] - 0.2
sb_035_color_variation02[1] = sb_035_color_variation02[1] - 0.2
sb_035_color_variation02[2] = sb_035_color_variation02[2] - 0.2
sb_035_color_variation02 = tuple(sb_035_color_variation02)

sb_035_color_variation03 = list(sb_035_color)
sb_035_color_variation03[0] = sb_035_color_variation03[0] - 0.3
sb_035_color_variation03[1] = sb_035_color_variation03[1] - 0.3
sb_035_color_variation03[2] = sb_035_color_variation03[2] - 0.3
sb_035_color_variation03 = tuple(sb_035_color_variation03)

sb_035_color_variation04 = list(sb_035_color)
sb_035_color_variation04[0] = sb_035_color_variation04[0] - 0.2
sb_035_color_variation04[1] = sb_035_color_variation04[1] - 0.4
sb_035_color_variation04[2] = sb_035_color_variation04[2] - 0.4
sb_035_color_variation04 = tuple(sb_035_color_variation04)

palette = sns.color_palette("hls", 8)
sb_025_color = palette[7]

sb_025_color_variation01 = list(sb_025_color)
sb_025_color_variation01[0] = sb_025_color_variation01[0] + 0.1
sb_025_color_variation01[1] = sb_025_color_variation01[1] + 0.1
sb_025_color_variation01[2] = sb_025_color_variation01[2] + 0.1
sb_025_color_variation01 = tuple(sb_025_color_variation01)

sb_025_color_variation02 = list(sb_025_color)
sb_025_color_variation02[0] = sb_025_color_variation02[0] - 0.1
sb_025_color_variation02[1] = sb_025_color_variation02[1] - 0.1
sb_025_color_variation02[2] = sb_025_color_variation02[2] - 0.1
sb_025_color_variation02 = tuple(sb_025_color_variation02)

# %% [markdown]
# # b1.0: Parameters grid = 1000 minwin = 100 maxwin = 1000

# %%
clean_up_OmegaPlus()

# %%
mkdir omegaplus-files

# %%
mu = 5e-5
grid = 1000 
minwin = 100
maxwin = 1000
paths = paths_b1

files_0 = []
for i, path in enumerate(tqdm(paths)):
    trees, _ = get_path_trees_recorders(path)        
    likelihood = multiprocessed_omegaplus(10)
    likelihood = pd.concat(likelihood)
    likelihood.columns = ['Position', 'Likelihood', 'run']
    clean_up_OmegaPlus()
    print("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
    pickle.dump(likelihood, open("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle","wb"))
    files_0.append("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
# Out:
#  20%|██        | 1/5 [05:54<23:39, 354.86s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-05_mus0_sc0_dc0_L1e4_sp0_s1_1000_100_1000.pickle
#  40%|████      | 2/5 [10:42<15:46, 315.45s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov0_1000_100_1000.pickle
#  60%|██████    | 3/5 [15:46<10:19, 309.96s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov500_1000_100_1000.pickle
#  80%|████████  | 4/5 [20:47<05:06, 306.49s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov1000_1000_100_1000.pickle
# 100%|██████████| 5/5 [25:56<00:00, 311.29s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov2000_1000_100_1000.pickle

# %%
files_0 = []
mu = 5e-5
grid = 1000 
minwin = 100
maxwin = 1000
paths = paths_b1
for i, path in enumerate(tqdm(paths)):
    files_0.append("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 91578.69it/s]

# %%
paths = paths_b1
files = files_0
likelihoods = get_likelihoods(paths, files)
sweeps = get_sweeps(models, likelihoods, np.arange(0, 3000, 100))
sweeps.sweeps = sweeps.sweeps / sweeps.sweeps.max()


sns.set(font_scale=1.8); sns.set_style("white"); plt.style.use('science')
fig, ax = plt.subplots(1, 1,figsize=(8, 6), sharex=True, sharey=False)
sns.lineplot(data=sweeps, x="threshold", y="sweeps", style="model", hue="model", linewidth=1.4,
             palette=["black", black_color_variation01 ,black_color_variation02, black_color_variation03, black_color_variation04], ax=ax)
plt.savefig('./figures/omega_1000_100_1000_b1.0.png', dpi=400, bbox_inches='tight')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 127.36it/s]

# %% [markdown]
# # b0.35: Parameters grid = 1000 minwin = 100 maxwin = 1000

# %%
mu = 5e-5
grid = 1000 
minwin = 100
maxwin = 1000
paths = paths_b035


files_2 = []
for i, path in enumerate(tqdm(paths)):
    trees, _ = get_path_trees_recorders(path)
    
    #trees = trees[:num_trees]
        
    likelihood = multiprocessed_omegaplus(10)
    likelihood = pd.concat(likelihood)
    likelihood.columns = ['Position', 'Likelihood', 'run']
    clean_up_OmegaPlus()
    print("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
    pickle.dump(likelihood, open("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle","wb"))
    files_2.append("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
# Out:
#  20%|██        | 1/5 [26:59<1:47:59, 1619.91s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-05_mus0_sc0_dc0_L1e4_sp0_s1_1000_100_1000.pickle
#  40%|████      | 2/5 [52:33<1:18:27, 1569.27s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov0_1000_100_1000.pickle
#  60%|██████    | 3/5 [1:19:05<52:38, 1579.44s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov500_1000_100_1000.pickle
#  80%|████████  | 4/5 [1:45:42<26:26, 1586.44s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov1000_1000_100_1000.pickle
# 100%|██████████| 5/5 [2:13:25<00:00, 1601.17s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov2000_1000_100_1000.pickle

# %%
files_2 = []
mu = 5e-5
grid = 1000 
minwin = 100
maxwin = 1000
paths = paths_b035
for i, path in enumerate(tqdm(paths)):
    files_2.append("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 59241.58it/s]

# %%
paths = paths_b035
files = files_2
likelihoods = get_likelihoods(paths, files)
sweeps = get_sweeps(models, likelihoods, np.arange(0, 3000, 100))
sweeps.sweeps = sweeps.sweeps / sweeps.sweeps.max()


sns.set(font_scale=1.8); sns.set_style("white"); plt.style.use('science')
fig, ax = plt.subplots(1, 1,figsize=(8, 6), sharex=True, sharey=False)
sns.lineplot(data=sweeps, x="threshold", y="sweeps", style="model",linewidth=1.4,
             hue="model",palette=[sb_035_color_variation04,sb_035_color_variation03, 
                                                                                         sb_035_color_variation02, sb_035_color_variation01, sb_035_color], ax=ax)
plt.savefig('./figures/omega_1000_100_1000_b0.35.png', dpi=400, bbox_inches='tight')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 35.68it/s]

# %% [markdown]
# # b0.35: Parameters grid = 1000 minwin = 50 maxwin = 100

# %%
mu = 5e-5
grid = 1000 
minwin = 50
maxwin = 100
paths = paths_b035


files_4 = []
for i, path in enumerate(tqdm(paths)):
    trees, _ = get_path_trees_recorders(path)
            
    likelihood = multiprocessed_omegaplus(10)
    likelihood = pd.concat(likelihood)
    likelihood.columns = ['Position', 'Likelihood', 'run']
    clean_up_OmegaPlus()
    print("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
    pickle.dump(likelihood, open("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle","wb"))
    files_4.append("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
# Out:
#  20%|██        | 1/5 [24:15<1:37:02, 1455.67s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-05_mus0_sc0_dc0_L1e4_sp0_s1_1000_50_100.pickle
#  40%|████      | 2/5 [47:08<1:10:19, 1406.66s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov0_1000_50_100.pickle
#  60%|██████    | 3/5 [1:10:07<46:28, 1394.13s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov500_1000_50_100.pickle
#  80%|████████  | 4/5 [1:39:07<25:30, 1530.72s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov1000_1000_50_100.pickle
# 100%|██████████| 5/5 [2:07:41<00:00, 1532.32s/it]
# ./omegaplus-files/N500_b0.35_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov2000_1000_50_100.pickle

# %%
files_4 = []
mu = 5e-5
grid = 1000 
minwin = 50
maxwin = 100
paths = paths_b035
for i, path in enumerate(tqdm(paths)):
    files_4.append("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 31871.61it/s]

# %%
paths = paths_b035
files = files_4
likelihoods = get_likelihoods(paths, files)
sweeps = get_sweeps(models, likelihoods, np.arange(0, 3000, 100))
sweeps.sweeps = sweeps.sweeps / sweeps.sweeps.max()

sns.set(font_scale=1.8); sns.set_style("white"); plt.style.use('science')
fig, ax = plt.subplots(1, 1,figsize=(8, 6), sharex=True, sharey=False)
sns.lineplot(data=sweeps, x="threshold", y="sweeps", style="model",linewidth=1.4, hue="model",palette=[sb_035_color_variation04,sb_035_color_variation03, 
                                                                                         sb_035_color_variation02, sb_035_color_variation01, sb_035_color], ax=ax)
plt.savefig('./figures/omega_1000_50_100_b0.35.png', dpi=400, bbox_inches='tight')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 34.63it/s]

# %% [markdown]
# # b1.0: Parameters grid = 1000 minwin = 50 maxwin = 100

# %%
mu = 5e-5
grid = 1000 
minwin = 50
maxwin = 100
paths = paths_b1


files_5 = []
for i, path in enumerate(tqdm(paths)):
    trees, _ = get_path_trees_recorders(path)
    
    #trees = trees[:num_trees]
        
    likelihood = multiprocessed_omegaplus(10)
    likelihood = pd.concat(likelihood)
    likelihood.columns = ['Position', 'Likelihood', 'run']
    clean_up_OmegaPlus()
    print("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
    pickle.dump(likelihood, open("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle","wb"))
    files_5.append("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
# Out:
#  20%|██        | 1/5 [06:28<25:55, 388.76s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-05_mus0_sc0_dc0_L1e4_sp0_s1_1000_50_100.pickle
#  40%|████      | 2/5 [12:12<18:07, 362.50s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov0_1000_50_100.pickle
#  60%|██████    | 3/5 [18:23<12:12, 366.22s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov500_1000_50_100.pickle
#  80%|████████  | 4/5 [25:11<06:22, 382.80s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov1000_1000_50_100.pickle
# 100%|██████████| 5/5 [32:12<00:00, 386.56s/it]
# ./omegaplus-files/N500_b1.0_m100_mu0_r5e-5_mus5e-10_sc1_dc0.5_L1e4_sp5e3_s1_recov2000_1000_50_100.pickle

# %%
files_5 = []
mu = 5e-5
grid = 1000 
minwin = 50
maxwin = 100
paths = paths_b1
for i, path in enumerate(tqdm(paths)):
    files_5.append("./omegaplus-files/" + basename(path[:-1]) + "_" + str(grid) + "_" + str(minwin) + "_" + str(maxwin) + ".pickle")
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 29454.38it/s]

# %%
paths = paths_b1
files = files_5
likelihoods = get_likelihoods(paths, files)
sweeps = get_sweeps(models, likelihoods, np.arange(0, 3000, 100))
sweeps.sweeps = sweeps.sweeps / sweeps.sweeps.max()

sns.set(font_scale=1.8); sns.set_style("white"); plt.style.use('science')
fig, ax = plt.subplots(1, 1,figsize=(8, 6), sharex=True, sharey=False)
sns.lineplot(data=sweeps, x="threshold", y="sweeps", style="model", hue="model", linewidth=1.4,
             palette=["black", black_color_variation01 ,black_color_variation02, black_color_variation03, black_color_variation04], ax=ax)
plt.savefig('./figures/omega_1000_50_100_b1.0.png', dpi=400, bbox_inches='tight')
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 91.87it/s]
